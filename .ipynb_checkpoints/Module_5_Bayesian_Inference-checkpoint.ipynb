# %%
import numpy as np
import pandas as pd

x = np.linspace(-5, 5, 20)
y = -5 + 3*x + 4*np.random.normal(size=x.shape)
data = pd.DataFrame({'x': x, 'y': y})

# %%
import pymc3 as pm

with pm.Model():
    
    # prior info
    intercept = pm.Uniform('intercept',-10,10)
    slope = pm.Uniform('slope',1,3)
    
    # likelihood
    y_ = pm.Normal('y_', 
                   mu = intercept+slope*x,
                   sd = 1,
                   observed = y)
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [slope, intercept]
# Sampling 4 chains: 100%|██████████| 42000/42000 [00:10<00:00, 4142.16draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x134a43ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133ac89e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x132e626a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a43f60>]],
#       dtype=object)

# %%
a = trace['intercept'].mean()
b = trace['slope'].mean()

yhat = a + b*x

import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x,y,'or')
plt.plot(x,yhat,'b')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import pandas as pd
mtcars = pd.read_csv('./data/mtcars.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7b2f8d9b9ad0> in <module>
#       9
#      10     # Expected value of outcome
# ---> 11     mu = alpha + beta[0]*X1 + beta[1]*X2
#      12
#      13     # Likelihood (sampling distribution) of observations
#
# NameError: name 'X1' is not defined

# %%
# %matplotlib inline

fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,4))
axes[0].scatter(X1, Y)
axes[1].scatter(X2, Y)
axes[0].set_ylabel('Y'); axes[0].set_xlabel('X1'); axes[1].set_xlabel('X2');

# %%
import numpy as np
import pandas as pd

import pymc3 as pm

n = 100
k = 61

with pm.Model() as coin_context:
    p = pm.Uniform('p',0.40,0.80)
    
    y = pm.Binomial('y',n=n,p=p,observed=k)
    
    trace = pm.sample(10000)

# %%
nsample = 100
x = np.linspace(0, 10, 100)
X = np.column_stack((x, x**2))
beta = np.array([1, 0.1, 10])
e = np.random.normal(size=nsample)

# %%
pd.DataFrame({'usa': usa1965.log10_income, 'china': china1965.log10_income}).boxplot()

# %%
import numpy as np

x = np.arange(1,10,1)
y = 2*x

# %%
model = sm.OLS(y,x)

# %%
result = model.fit()
result.summary()

# %%
import pandas as pd
mtcars = pd.read_csv("./data/mtcars.csv")
#mtcars = sm.datasets.get_rdataset("mtcars").data

# %%
mtcars.plot.scatter('mpg','hp')

# %%
model = sm.OLS(mtcars.hp,mtcars.mpg)

# %%
result = model.fit()

# %%
result.summary()

# %%
model = smf.ols('hp - mpg', data=mtcars)

# %%
lm.summary()

# %%
# fix error in some versions of statsmodels
import scipy
if not hasattr(scipy.stats,'chisqprob'):
    scipy.stats.chisqprob = lambda chisq, df: scipy.stats.chi2.sf(chisq, df)

# %%
import pandas as pd
smoking = pd.read_csv("./data/whickham.csv")

# %%
smoking = smoking[smoking.age < 65]

# %%
import numpy as np
import matplotlib.pyplot as plt

color = np.where(smoking.smoker == 'No','skyblue','coral')
jitter = 0.05*(np.random.rand(len(smoking)) - 0.5)
def plotfit(fit):
    plt.scatter(smoking.age,smoking.outcome + jitter,c=color,linewidth=0.2,edgecolor='k',alpha=0.5)
    plt.scatter(smoking.age,fit.predict(smoking),c=color,linewidth=0.2,edgecolor='gray',marker='d')

# %%
smoking['outcome'] = 1*(smoking['outcome'] == 'Alive')

# %%
ols_group_age = smf.ols('outcome ~ smoker + age',data=smoking).fit()

# %%
plotfit(ols_group_age)

# %%
sm.stats.anova_lm(ols_group_age)

# %%
ols_group_age.conf_int()

# %%
logit_smoker_age = smf.logit('outcome ~ smoker + age',data=smoking).fit()

# %%
plotfit(logit_smoker_age)

# %%
logit_smoker_age.summary()
